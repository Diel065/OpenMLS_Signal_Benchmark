# %%
source("statistics_analysis_openmls_v3.R")

options(repr.plot.width = 18, repr.plot.height = 8)
openmls_v3_df <- read_openmls_v3_raw()
summarise_openmls_v3_data(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: commit_create_protocol_add

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_commit_add(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: commit_create_protocol_remove

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_commit_remove(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: commit_create_protocol_update

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_commit_update(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: join_from_welcome_protocol

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_join_from_welcome(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: application_message_create_protocol

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_application_message_create(openmls_v3_df)

# %% [markdown]
# ## OpenMLS: application_message_receive_protocol

# %%
options(repr.plot.width = 18, repr.plot.height = 8)
plot_openmls_application_message_receive(openmls_v3_df)
